# %%
# If needed you can install a package in the current AppHub Jupyter environment using pip
# For instance, we will need at least the following libraries
import sys
# !{sys.executable} -m pip install --upgrade pyeodh pandas matplotlib numpy pillow folium xarray geoviews
# Out:
# Requirement already satisfied: pyeodh in /home/ubuntu/code/.venv/lib/python3.12/site-packages (0.0.14)
# Requirement already satisfied: pandas in /home/ubuntu/code/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /home/ubuntu/code/.venv/lib/python3.12/site-packages (3.10.0)
# Requirement already satisfied: numpy in /home/ubuntu/code/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: pillow in /home/ubuntu/code/.venv/lib/python3.12/site-packages (11.1.0)
# Requirement already satisfied: folium in /home/ubuntu/code/.venv/lib/python3.12/site-packages (0.19.4)
# Requirement already satisfied: xarray in /home/ubuntu/code/.venv/lib/python3.12/site-packages (2025.1.2)
# Requirement already satisfied: geoviews in /home/ubuntu/code/.venv/lib/python3.12/site-packages (1.14.0)
# Requirement already satisfied: owslib<0.32.0,>=0.31.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from pyeodh) (0.31.0)
# Requirement already satisfied: pystac<2.0.0,>=1.10.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from pyeodh) (1.12.2)
# Requirement already satisfied: requests-oauthlib<3.0.0,>=2.0.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from pyeodh) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: branca>=0.6.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from folium) (3.1.5)
# Requirement already satisfied: requests in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from folium) (2025.1.0)
# Requirement already satisfied: bokeh>=3.6.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from geoviews) (3.6.3)
# Requirement already satisfied: cartopy>=0.18.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from geoviews) (0.24.1)
# Requirement already satisfied: holoviews>=1.16.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from geoviews) (1.20.1)
# Requirement already satisfied: panel>=1.0.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from geoviews) (1.6.1)
# Requirement already satisfied: param<3.0,>=1.9.3 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from geoviews) (2.2.0)
# Requirement already satisfied: pyproj in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from geoviews) (3.7.1)
# Requirement already satisfied: shapely in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from geoviews) (2.0.7)
# Requirement already satisfied: PyYAML>=3.10 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from bokeh>=3.6.0->geoviews) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from bokeh>=3.6.0->geoviews) (6.4.2)
# Requirement already satisfied: pyshp>=2.3 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: colorcet in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from holoviews>=1.16.0->geoviews) (3.1.0)
# Requirement already satisfied: pyviz-comms>=2.1 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from holoviews>=1.16.0->geoviews) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: lxml in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from owslib<0.32.0,>=0.31.0->pyeodh) (5.3.1)
# Requirement already satisfied: bleach in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (6.2.0)
# Requirement already satisfied: linkify-it-py in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (2.0.3)
# Requirement already satisfied: markdown in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (3.7)
# Requirement already satisfied: markdown-it-py in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (0.4.2)
# Requirement already satisfied: tqdm in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (4.67.1)
# Requirement already satisfied: typing-extensions in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (4.12.2)
# Requirement already satisfied: certifi in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from pyproj->geoviews) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from requests-oauthlib<3.0.0,>=2.0.0->pyeodh) (3.2.2)
# Requirement already satisfied: webencodings in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /home/ubuntu/code/.venv/lib/python3.12/site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.2)

# %%
# Imports
import os

# Import the Python API Client
import pyeodh

import folium

import geoviews as gv

# Parameterise geoviews
gv.extension("bokeh", "matplotlib")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='606c51fd-2d6f-4d50-9b46-95cf2f85e131'>
#   <div id="aff5117e-a809-4a7a-a2be-4fba8db1dee3" data-root-id="606c51fd-2d6f-4d50-9b46-95cf2f85e131" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f61fd734-aec2-41d4-bfed-acd24fcd0174":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"606c51fd-2d6f-4d50-9b46-95cf2f85e131"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"6e46b6b6-7f14-41fa-8f0f-5751d32cf2d8","attributes":{"plot_id":"606c51fd-2d6f-4d50-9b46-95cf2f85e131","comm_id":"ffe97c50d9284b2585afe1c9ce2a2adb","client_comm_id":"23694ec4440c4ea6b4eb4b4e7008fbab"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"f61fd734-aec2-41d4-bfed-acd24fcd0174","roots":{"606c51fd-2d6f-4d50-9b46-95cf2f85e131":"aff5117e-a809-4a7a-a2be-4fba8db1dee3"},"root_ids":["606c51fd-2d6f-4d50-9b46-95cf2f85e131"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %% [markdown]
# ## Retrieve Different DataTypes

# %%
# Connect to the Hub
client = pyeodh.Client().get_catalog_service()

catalog = client.get_catalog("supported-datasets/ceda-stac-catalogue")

# Get the collection
cmip6 = catalog.get_collection("cmip6")
sentinel2_ard = catalog.get_collection("sentinel2_ard")

# Get the collection metadata
cmip6.extent.to_dict()
sentinel2_ard.extent.to_dict()

# Look for a specific item
cmip6_item = cmip6.get_item(
    "CMIP6.ScenarioMIP.THU.CIESM.ssp585.r1i1p1f1.Amon.rsus.gr.v20200806"
)
sentinel_item = sentinel2_ard.get_item(
    "neodc.sentinel_ard.data.sentinel_2.2023.11.21.S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65"
)

print(cmip6_item.assets)
print(sentinel_item.assets)

cmip6_kerchunk_asset = cmip6_item.assets["reference_file"]
sentinel2_ard_cog_asset = sentinel_item.assets["cog"]

# print the href
print(cmip6_kerchunk_asset.href)
print(sentinel2_ard_cog_asset.href)
# Out:
# {'reference_file': <Asset href=https://dap.ceda.ac.uk/badc/cmip6/metadata/kerchunk/pipeline1/ScenarioMIP/THU/CIESM/kr1.0/CMIP6_ScenarioMIP_THU_CIESM_ssp585_r1i1p1f1_Amon_rsus_gr_v20200806_kr1.0.json>, 'data0001': <Asset href=https://dap.ceda.ac.uk/badc/cmip6/data/CMIP6/ScenarioMIP/THU/CIESM/ssp585/r1i1p1f1/Amon/rsus/gr/v20200806/rsus_Amon_CIESM_ssp585_r1i1p1f1_gr_402901-411412.nc>}
# {'cloud': <Asset href=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_clouds.tif>, 'cloud_probability': <Asset href=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_clouds_prob.tif>, 'cog': <Asset href=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_vmsk_sharp_rad_srefdem_stdsref.tif>, 'metadata': <Asset href=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_vmsk_sharp_rad_srefdem_stdsref_meta.xml>, 'saturated_pixels': <Asset href=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_sat.tif>, 'thumbnail': <Asset href=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_vmsk_sharp_rad_srefdem_stdsref_thumbnail.jpg>, 'topographic_shadow': <Asset href=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_toposhad.tif>, 'valid_pixels': <Asset href=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_valid.tif>}
# https://dap.ceda.ac.uk/badc/cmip6/metadata/kerchunk/pipeline1/ScenarioMIP/THU/CIESM/kr1.0/CMIP6_ScenarioMIP_THU_CIESM_ssp585_r1i1p1f1_Amon_rsus_gr_v20200806_kr1.0.json
# https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_vmsk_sharp_rad_srefdem_stdsref.tif

# %% [markdown]
# ## Preview the Data

# %% [markdown]
# ### COG (Preview)

# %% [markdown]
# Here we can use the `Preview` feature to customise some of the parameters we are going to use to dynamically visualise the data.
#
# - `bidx` is the band index we want to preview. In this case, we are previewing the first band.
# - `rescale` is the range of values we want to display. In this case, we are rescaling the values between 9 and 255.
# - `colormap_name` is the name of the colormap we want to use. In this case, we are using the `rain_r` colormap.
#
# For testing, experiment with different colormaps, here's a few to try:
#
# `'accent', 'accent_r', 'afmhot', 'afmhot_r', 'algae', 'algae_r', 'amp', 'amp_r', 'autumn', 'autumn_r', 'balance', 'balance_r', 'binary', 'binary_r', 'blues', 'blues_r', 'bone', 'bone_r', 'brbg', 'brbg_r', 'brg', 'brg_r', 'bugn', ...`

# %%
import requests
from IPython.display import Image, display

ENVIRONMENT = 'staging'

COG_PREVIEW_URL = f'https://{ENVIRONMENT}.eodatahub.org.uk/titiler/core/cog/preview'
COG_PREVIEW_PARAMS = {
    'url': sentinel2_ard_cog_asset.href,
    'bidx': 1,
    'rescale': '9,255',
    'colormap_name': 'rain_r'
}

response = requests.get(COG_PREVIEW_URL, params=COG_PREVIEW_PARAMS)

# Display the image
image = Image(response.content)
display(image)

# %% [markdown]
# ### XArray Data - Kerchunk (Preview)

# %% [markdown]
# Lets follow a similar approach for the XArray data. This Xarray data is a Kerchunk dataset, which is a dataset that contains a single variable `rsus`. We can preview the data similarly to how we previewed the COG data.
#
# This time, focus on the `rescale` parameter. This parameter is used to rescale the values of the data. In this example we are rescaling between `-50,100`, but try something new like `50,400` and see how the data changes.

# %%
import requests
from IPython.display import Image, display

ENVIRONMENT = 'staging'

XARRAY_PREVIEW_URL = f'https://{ENVIRONMENT}.eodatahub.org.uk/titiler/xarray/tiles/0/0/0'
XARRAY_PARAMS = {
    'url': cmip6_kerchunk_asset.href,
    'variable': 'rsus',
    'rescale': '-50,100',
    'colormap_name': 'plasma',
    'reference' : 'true'
}

constructed_url = f'{XARRAY_PREVIEW_URL}?url={cmip6_kerchunk_asset.href}&variable=rsus&rescale=35,400&colormap_name=plasma&reference=true'

print(constructed_url)

response = requests.get(XARRAY_PREVIEW_URL, params=XARRAY_PARAMS)

# Display the image
image = Image(response.content)
display(image)
# Out:
# https://staging.eodatahub.org.uk/titiler/xarray/tiles/0/0/0?url=https://dap.ceda.ac.uk/badc/cmip6/metadata/kerchunk/pipeline1/ScenarioMIP/THU/CIESM/kr1.0/CMIP6_ScenarioMIP_THU_CIESM_ssp585_r1i1p1f1_Amon_rsus_gr_v20200806_kr1.0.json&variable=rsus&rescale=35,400&colormap_name=plasma&reference=true

# %% [markdown]
# ## Exploring the Data Using OGC XYZ Tiles

# %% [markdown]
# Now that we are done previewing, see how we can use third party tools to also explore the data. To do this, we are going to create an `XYZ` tile endpoint for the COG data and the XArray data. This can then be used in any third-party tool that supports XYZ tiles i.e. QGIS, OpenLayers, Leaflet, etc.

# %%
# Generate XYZ For COG
COG_OGC_URL = 'https://' + ENVIRONMENT + '.eodatahub.org.uk/titiler/core/cog/tiles/WebMercatorQuad/{z}/{x}/{y}'
COG_XYZ = COG_OGC_URL + '?' + '&'.join([f'{k}={v}' for k, v in COG_PREVIEW_PARAMS.items()])

# Generate XYZ For Xarray
XARRAY_OGC_URL = 'https://' + ENVIRONMENT + '.eodatahub.org.uk/titiler/xarray/tiles/WebMercatorQuad/{z}/{x}/{y}'
XARRAY_XYZ = XARRAY_OGC_URL + '?' + '&'.join([f'{k}={v}' for k, v in XARRAY_PARAMS.items()])

print('Cog XYZ: ', COG_XYZ)
print('Kerchunk XYZ', XARRAY_XYZ)
# Out:
# Cog XYZ:  https://staging.eodatahub.org.uk/titiler/core/cog/tiles/WebMercatorQuad/{z}/{x}/{y}?url=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_vmsk_sharp_rad_srefdem_stdsref.tif&bidx=1&rescale=9,255&colormap_name=rain_r
# Kerchunk XYZ https://staging.eodatahub.org.uk/titiler/xarray/tiles/WebMercatorQuad/{z}/{x}/{y}?url=https://dap.ceda.ac.uk/badc/cmip6/metadata/kerchunk/pipeline1/ScenarioMIP/THU/CIESM/kr1.0/CMIP6_ScenarioMIP_THU_CIESM_ssp585_r1i1p1f1_Amon_rsus_gr_v20200806_kr1.0.json&variable=rsus&rescale=-50,100&colormap_name=plasma&reference=true

# %% [markdown]
# ### Visualise COG Data on the Map

# %%
m = folium.Map(location=[54.5, -4.5], zoom_start=6)

# Add the TiTiler layer
folium.raster_layers.TileLayer(
    tiles=COG_XYZ,
    attr="TiTiler",
    name="Sentinel 2 ARD Scene",
    overlay=True
).add_to(m)

# Add a layer control
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cd8ee23429940da18b24e887882a806 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cd8ee23429940da18b24e887882a806&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cd8ee23429940da18b24e887882a806 = L.map(
#                 &quot;map_3cd8ee23429940da18b24e887882a806&quot;,
#                 {
#                     center: [54.5, -4.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e293c0986d28be134d1f83a57371e4b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e293c0986d28be134d1f83a57371e4b1.addTo(map_3cd8ee23429940da18b24e887882a806);
#
#
#             var tile_layer_b8e06ab0ffa6b5f96014baff7291c3ea = L.tileLayer(
#                 &quot;https://staging.eodatahub.org.uk/titiler/core/cog/tiles/WebMercatorQuad/{z}/{x}/{y}?url=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_vmsk_sharp_rad_srefdem_stdsref.tif\u0026bidx=1\u0026rescale=9,255\u0026colormap_name=rain_r&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;TiTiler&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8e06ab0ffa6b5f96014baff7291c3ea.addTo(map_3cd8ee23429940da18b24e887882a806);
#
#
#             var layer_control_ca2ce3786f660e5d18c87587382121b8_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e293c0986d28be134d1f83a57371e4b1,
#                 },
#                 overlays :  {
#                     &quot;Sentinel 2 ARD Scene&quot; : tile_layer_b8e06ab0ffa6b5f96014baff7291c3ea,
#                 },
#             };
#             let layer_control_ca2ce3786f660e5d18c87587382121b8 = L.control.layers(
#                 layer_control_ca2ce3786f660e5d18c87587382121b8_layers.base_layers,
#                 layer_control_ca2ce3786f660e5d18c87587382121b8_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_3cd8ee23429940da18b24e887882a806);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Visualise XArray Data on the Map

# %%
m = folium.Map(location=[0, 0], zoom_start=2)

# Add the TiTiler layer
folium.raster_layers.TileLayer(
    tiles=XARRAY_XYZ,
    attr="TiTiler",
    name="Sentinel 2 ARD Scene",
    overlay=True
).add_to(m)

# Add a layer control
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c433d4655aea09ade3b313114bd9cbf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c433d4655aea09ade3b313114bd9cbf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c433d4655aea09ade3b313114bd9cbf = L.map(
#                 &quot;map_7c433d4655aea09ade3b313114bd9cbf&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_460171f7e774fb845e0dabb22a1e305d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_460171f7e774fb845e0dabb22a1e305d.addTo(map_7c433d4655aea09ade3b313114bd9cbf);
#
#
#             var tile_layer_0d7c4d1a14bb27ff7a7db3106e5df181 = L.tileLayer(
#                 &quot;https://staging.eodatahub.org.uk/titiler/xarray/tiles/WebMercatorQuad/{z}/{x}/{y}?url=https://dap.ceda.ac.uk/badc/cmip6/metadata/kerchunk/pipeline1/ScenarioMIP/THU/CIESM/kr1.0/CMIP6_ScenarioMIP_THU_CIESM_ssp585_r1i1p1f1_Amon_rsus_gr_v20200806_kr1.0.json\u0026variable=rsus\u0026rescale=-50,100\u0026colormap_name=plasma\u0026reference=true&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;TiTiler&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d7c4d1a14bb27ff7a7db3106e5df181.addTo(map_7c433d4655aea09ade3b313114bd9cbf);
#
#
#             var layer_control_683917e46033a049d18388be1dc81b8c_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_460171f7e774fb845e0dabb22a1e305d,
#                 },
#                 overlays :  {
#                     &quot;Sentinel 2 ARD Scene&quot; : tile_layer_0d7c4d1a14bb27ff7a7db3106e5df181,
#                 },
#             };
#             let layer_control_683917e46033a049d18388be1dc81b8c = L.control.layers(
#                 layer_control_683917e46033a049d18388be1dc81b8c_layers.base_layers,
#                 layer_control_683917e46033a049d18388be1dc81b8c_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_7c433d4655aea09ade3b313114bd9cbf);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Visualising them Together

# %%
# Start over UK
m = folium.Map(location=[54.5, -4.5], zoom_start=3)

# Add the XArray layer
folium.raster_layers.TileLayer(
    tiles=XARRAY_XYZ,
    attr="TiTiler",
    name="CMIP6 Kerchunk",
    overlay=True,
    opacity=0.5
).add_to(m)

# Add the COG layer
folium.raster_layers.TileLayer(
    tiles=COG_XYZ,
    attr="TiTiler",
    name="Sentinel 2 ARD Scene",
    overlay=True
).add_to(m)

# Add a layer control
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e0ad12a769f4e66e3f44195294c4a50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e0ad12a769f4e66e3f44195294c4a50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e0ad12a769f4e66e3f44195294c4a50 = L.map(
#                 &quot;map_4e0ad12a769f4e66e3f44195294c4a50&quot;,
#                 {
#                     center: [54.5, -4.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76129155665dccb694f3328e3e7881ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76129155665dccb694f3328e3e7881ad.addTo(map_4e0ad12a769f4e66e3f44195294c4a50);
#
#
#             var tile_layer_fe4fd87c94d04b662ff3ab19093e177a = L.tileLayer(
#                 &quot;https://staging.eodatahub.org.uk/titiler/xarray/tiles/WebMercatorQuad/{z}/{x}/{y}?url=https://dap.ceda.ac.uk/badc/cmip6/metadata/kerchunk/pipeline1/ScenarioMIP/THU/CIESM/kr1.0/CMIP6_ScenarioMIP_THU_CIESM_ssp585_r1i1p1f1_Amon_rsus_gr_v20200806_kr1.0.json\u0026variable=rsus\u0026rescale=-50,100\u0026colormap_name=plasma\u0026reference=true&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;TiTiler&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 0.5,
# }
#
#             );
#
#
#             tile_layer_fe4fd87c94d04b662ff3ab19093e177a.addTo(map_4e0ad12a769f4e66e3f44195294c4a50);
#
#
#             var tile_layer_1cc4e4cf94cf78f556bcf7b3fb2b4315 = L.tileLayer(
#                 &quot;https://staging.eodatahub.org.uk/titiler/core/cog/tiles/WebMercatorQuad/{z}/{x}/{y}?url=https://dap.ceda.ac.uk/neodc/sentinel_ard/data/sentinel_2/2023/11/21/S2B_20231121_latn536lonw0052_T30UUE_ORB123_20231121122846_utm30n_TM65_vmsk_sharp_rad_srefdem_stdsref.tif\u0026bidx=1\u0026rescale=9,255\u0026colormap_name=rain_r&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;TiTiler&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1cc4e4cf94cf78f556bcf7b3fb2b4315.addTo(map_4e0ad12a769f4e66e3f44195294c4a50);
#
#
#             var layer_control_f8231489f336c72f54b91d149c841576_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_76129155665dccb694f3328e3e7881ad,
#                 },
#                 overlays :  {
#                     &quot;CMIP6 Kerchunk&quot; : tile_layer_fe4fd87c94d04b662ff3ab19093e177a,
#                     &quot;Sentinel 2 ARD Scene&quot; : tile_layer_1cc4e4cf94cf78f556bcf7b3fb2b4315,
#                 },
#             };
#             let layer_control_f8231489f336c72f54b91d149c841576 = L.control.layers(
#                 layer_control_f8231489f336c72f54b91d149c841576_layers.base_layers,
#                 layer_control_f8231489f336c72f54b91d149c841576_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_4e0ad12a769f4e66e3f44195294c4a50);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Conclusion
#
# In this notebook, we have seen how to preview different data types and how to visualise them on the map. We have also seen how to create an XYZ tile endpoint for the data, which can be used in any third-party tool that supports XYZ tiles.
#
# Extra functionality includes the ability to visualise your own Workspace data. By passing in your Workspace API key that you can generate from the `Workspace` tab, you can visualise your own data on the map.
#
# This means you can visualise any of your workflow outputs, commercial data or any other visualisable data you have in your Workspace.
#
# An example request would be:
# ```python
# TITILER_PREVIEW_URL = f'https://{environment}.eodatahub.org.uk/titiler/core/cog/preview'
# TITILER_PREVIEW_PARAMS = {
#     'url': WORKFLOW_OUTPUT_ASSET,
#     'bidx': 1,
#     'rescale': '9,255',
#     'colormap_name': 'rain_r'
# }
#
# response = requests.get(TITILER_PREVIEW_URL, params=TITILER_PREVIEW_PARAMS, headers={'Authorization': f'Bearer {WORKSPACE_API_KEY}'}) # Note the headers parameter
# ```
#
# Here we are passing the `WORKSPACE_API_KEY` in the headers of the request. This will allow you to visualise your own private data straight from the Platform. This works with QGIS as well, just create an Authentication configuration with the `Bearer` token and you can visualise your own private data in QGIS (or any other tool that supports XYZ tiles).
